# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\Classwork\IndustrialTraining2k23\Projects\Recommendation Systems\MusicRecommendationSystem\Dataset\SpotifyData\songdata.csv")
df.head(3)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df = df.sample(n=5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.shape
# Out:
# (5000, 3)

# %%
df
# Out:
#                         artist                      song  \
# 0                  Deep Purple                   Lucille
# 1     Electric Light Orchestra             A Better Life
# 2                 Fall Out Boy      Coffee's For Closers
# 3                   Mary Black                Moon River
# 4              Luther Vandross          Nights In Harlem
# ...                        ...                       ...
# 4995            Paul McCartney                Here Today
# 4996                 Tom Jones           Sunny Afternoon
# 4997                   Pitbull                 Descarada
# 4998                   Tiffany  I Saw Him Standing There
# 4999                 Freestyle         Hidden Freestlyes
#
#                                                    text
# 0     Lucille, won't you do your sister's will?  \nO...
# 1     Hush little baby, don't you cry  \nOh-oh, don'...
# 2     I can't explain a thing  \nI want everything  ...
# ...

# %% [markdown]
# ### Cleaning:

# %%
df['song'][0]
# Out:
# 'Lucille'

# %%
df['text'][0]
# Out:
# "Lucille, won't you do your sister's will?  \nOh, Lucille, won't you do your sister's will?  \nWell, you ran away and left, I love you still.  \nLucille, please, come back where you belong.  \n  \nOh, Lucille, please, come back where you belong.  \nI been good to you, baby, please, don't leave me alone.  \nLucille, baby, satisfy my heart.  \nOh, Lucille, baby, satisfy my heart.  \n  \nI slaved for you, baby, and gave you such a wonderful start.  \nI woke up this morning, Lucille was not in sight.  \nI asked her friends about her but all their lips were tight.  \n  \nLucille, please, come back where you belong.  \nI been good to you, baby, please, don't leave me alone.\n\n"

# %%
df['text'] = df['text'].str.lower().replace(r'[^\w\s]','').replace(r'\n',' ',regex=True)

# %%
df['text'][0]
# Out:
# "lucille, won't you do your sister's will?   oh, lucille, won't you do your sister's will?   well, you ran away and left, i love you still.   lucille, please, come back where you belong.      oh, lucille, please, come back where you belong.   i been good to you, baby, please, don't leave me alone.   lucille, baby, satisfy my heart.   oh, lucille, baby, satisfy my heart.      i slaved for you, baby, and gave you such a wonderful start.   i woke up this morning, lucille was not in sight.   i asked her friends about her but all their lips were tight.      lucille, please, come back where you belong.   i been good to you, baby, please, don't leave me alone.  "

# %%
import nltk

nltk.download('punkt')

from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Rajneesh
# [nltk_data]     Rajan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['text'] = df['text'].apply(lambda x: tokenization(x))

# %%
df['text']
# Out:
# 0       lucil , wo n't you do your sister 's will ? oh...
# 1       hush littl babi , do n't you cri oh-oh , do n'...
# 2       i ca n't explain a thing i want everyth to cha...
# 3       moon river , wider than a mile i 'm cross you ...
# 4       there 's a parti in harlem , come on i like to...
#                               ...
# 4995    and if i said , i realli knew you well what wo...
# 4996    in the summertim the taxman 's taken all my do...
# 4997    tu baila como una descarada pero a mi me encan...
# 4998    well he wa just seventeen if you know what i m...
# 4999    i tell you to sit down put you in tear she wan...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similarity = cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.05053112, 0.04482268, ..., 0.00459773, 0.02130053,
#        0.01326923])

# %%
df[df['song']=='Walking Away']
# Out:
# Empty DataFrame
# Columns: [artist, song, text]
# Index: []

# %%
sorted(list(enumerate(similarity[0])),reverse=False,key=lambda x:x[1])
# Out:
# [(7, 0.0),
#  (19, 0.0),
#  (62, 0.0),
#  (77, 0.0),
#  (96, 0.0),
#  (98, 0.0),
#  (103, 0.0),
#  (107, 0.0),
#  (127, 0.0),
#  (146, 0.0),
#  (174, 0.0),
#  (241, 0.0),
#  (260, 0.0),
#  (270, 0.0),
#  (271, 0.0),
#  (316, 0.0),
#  (337, 0.0),
#  (349, 0.0),
#  (393, 0.0),
#  (395, 0.0),
#  (411, 0.0),
#  (423, 0.0),
#  (436, 0.0),
#  (465, 0.0),
#  (481, 0.0),
#  (496, 0.0),
#  (502, 0.0),
#  (575, 0.0),
#  (579, 0.0),
#  (598, 0.0),
#  (626, 0.0),
#  (654, 0.0),
#  (701, 0.0),
#  (735, 0.0),
#  (753, 0.0),
#  (761, 0.0),
#  (768, 0.0),
#  (773, 0.0),
#  (795, 0.0),
#  (840, 0.0),
#  (844, 0.0),
#  (859, 0.0),
#  (877, 0.0),
#  (886, 0.0),
#  (907, 0.0),
#  (926, 0.0),
#  (936, 0.0),
#  (942, 0.0),
#  (943, 0.0),
#  (960, 0.0),
#  (987, 0.0),
#  (1010, 0.0),
#  (1034, 0.0),
#  (1061, 0.0),
#  (1093, 0.0),
#  (1158, 0.0),
#  (1185, 0.0),
#  (1239, 0.0),
#  (1281, 0.0),
#  (1295, 0.0),
#  (1315, 0.0),
#  (1317, 0.0),
#  (1344, 0.0),
#  (1419, 0.0),
#  (1441, 0.0),
#  (1455, 0.0),
# ...

# %%
df
# Out:
#                         artist                      song  \
# 0                  Deep Purple                   Lucille
# 1     Electric Light Orchestra             A Better Life
# 2                 Fall Out Boy      Coffee's For Closers
# 3                   Mary Black                Moon River
# 4              Luther Vandross          Nights In Harlem
# ...                        ...                       ...
# 4995            Paul McCartney                Here Today
# 4996                 Tom Jones           Sunny Afternoon
# 4997                   Pitbull                 Descarada
# 4998                   Tiffany  I Saw Him Standing There
# 4999                 Freestyle         Hidden Freestlyes
#
#                                                    text
# 0     lucil , wo n't you do your sister 's will ? oh...
# 1     hush littl babi , do n't you cri oh-oh , do n'...
# 2     i ca n't explain a thing i want everyth to cha...
# ...

# %%
def recommendation(song):
    idx = df[df['song'] == song].index[0]
    distances = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])
    
    songs = []
    for m_id in distances[1:11]:
        songs.append(df.iloc[m_id[0]].song)
        
    return songs

# %%
recommendation('Lucille')
# Out:
# ["Baby Please Don't Go",
#  'Let Me Get In Your Way',
#  'All I Need',
#  'Heavy Whispers',
#  'Behind That Locked Door',
#  'The Beautiful Ones',
#  'Go',
#  'Please Stay',
#  'Come Back Baby',
#  'You Belong To Me']

# %%
recommendation('Moon River')
# Out:
# ['Moon River',
#  'Moon River',
#  'Hardware Store',
#  "I'm Goin'",
#  'A River For Him',
#  'C Moon',
#  "Just Keep A Movin'",
#  'My World Begins And Ends With You',
#  "I'll Find You",
#  'Aqueous Transmission']

# %%
import pickle
pickle.dump(df.to_dict(),open('songs_dict.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))
